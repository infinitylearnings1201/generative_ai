# %% [markdown]
# <a href="https://colab.research.google.com/github/infinitylearnings1201/generative_ai/blob/genai_media_entertainment/Experiment1_Using_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world!!")
print("testing LLMs and experimenting use case in financial services.")
# Out:
# hello world!!
# testing LLMs and experimenting use case in financial services.

# %%
print("testing the financial services!!")
# Out:
# testing the financial services!!

# %%
#Financial Services
print("creating application in financial services and LLM")
# Out:
# creating application in financial services and LLM
